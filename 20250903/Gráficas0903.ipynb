# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def datos_cinetica(archivo_csv):
    df = pd.read_csv(archivo_csv, sep=';')
    df_datos = df[["Time", "GPolarization", "I1", "I2",]]
    return df_datos

def datos_espectro(archivo_csv):
    df = pd.read_csv(archivo_csv, sep=';')
    df_datos = df[["EmissionWavelength", "Intensity"]]
    return df_datos

# %%
CINE1 = datos_cinetica('cinetica_550.csv')
CINE2 = datos_cinetica('cinetica02_550.csv')
CINE3 = datos_cinetica('Cinetica_540.csv')
NEG = datos_cinetica('Control negativo_cinetica_540.csv')
MSC = datos_espectro('Espectro_sin_CCCP.csv')
MCC = datos_espectro('Espectro_con_CCCP .csv')

# %% [markdown]
# ## Cinética

# %% [markdown]
# Primera prueba 550

# %%
plt.scatter(CINE1["Time"], CINE1["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
plt.scatter(CINE1["Time"], CINE1["I2"], marker='o', color='crimson', label= 'I2=550 nm')
#plt.title('Cinética 0.5 s$\muL$')
plt.xlabel('Tiempo (s)') 
plt.ylabel('Intensidad')
plt.legend()
plt.grid()
plt.show()

# %%
plt.scatter(CINE1["Time"], CINE1["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %%
plt.scatter(CINE1["Time"], -CINE1["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Segunda prueba 550

# %%
plt.scatter(CINE2["Time"], CINE2["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
plt.scatter(CINE2["Time"], CINE2["I2"], marker='o', color='crimson', label= 'I2=550 nm')
#plt.title('Cinética 0.5 s$\muL$')
plt.xlabel('Tiempo (s)') 
plt.ylabel('Intensidad')
plt.legend(loc="center left")
plt.grid()
plt.show()

fig, axs = plt.subplots(ncols=2, figsize=(7, 2.5), constrained_layout=True)
axs[0].plot(CINE2["Time"], CINE2["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
axs[0].legend(loc="upper left")
axs[0].grid()
axs[1].plot(CINE2["Time"], CINE2["I2"], marker='o', color='crimson', label= 'I2=550 nm')
axs[1].legend(loc="upper left")
axs[1].grid()

# %%
plt.scatter(CINE2["Time"], CINE2["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %%
CINE2.index[CINE2["Time"] > 800]
mayores_800_550 = CINE2[CINE2["Time"] > 800] #filtrado cccp
# Out:
#         Time  GPolarization        I1       I2
# 132   801.45       0.476897  144408.0  51148.0
# 133   807.44       0.474951  144408.0  51406.0
# 134   813.45       0.473914  144078.0  51426.0
# 135   819.42       0.477244  144018.0  50964.0
# 136   825.43       0.476667  144074.0  51060.0
# 137   831.41       0.437255  143290.0  56104.0
# 138   837.41       0.460762  159746.0  58970.0
# 139   843.41       0.542181  205090.0  60884.0
# 140   849.38       0.574990  226578.0  61142.0
# 141   855.39       0.588657  235180.0  60894.0
# 142   861.39       0.599198  240070.0  60168.0
# 143   867.37       0.607668  244282.0  59614.0
# 144   873.35       0.610371  245084.0  59298.0
# 145   879.35       0.612316  246586.0  59292.0
# 146   885.31       0.615280  245626.0  58502.0
# 147   891.32       0.615831  246516.0  58610.0
# 148   897.31       0.614731  246290.0  58764.0
# 149   903.31       0.614504  246714.0  58908.0
# 150   909.31       0.616433  246978.0  58606.0
# ...

# %%
plt.scatter(mayores_800_550["Time"], -mayores_800_550["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Prueba 540

# %%
plt.plot(CINE3["Time"], CINE3["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
plt.plot(CINE3["Time"], CINE3["I2"], marker='o', color='crimson', label= 'I2=540 nm')
#plt.title('Cinética 0.5 s$\muL$')
plt.xlabel('Tiempo (s)') 
plt.ylabel('Intensidad')
plt.legend(loc="center left")
plt.grid()
plt.show()

fig, axs = plt.subplots(ncols=2, figsize=(7, 2.5), constrained_layout=True)
axs[0].plot(CINE3["Time"], CINE3["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
axs[0].legend(loc="upper left")
axs[0].grid()
axs[1].plot(CINE3["Time"], CINE3["I2"], marker='o', color='crimson', label= 'I2=540 nm')
axs[1].legend(loc="upper right")
axs[1].grid()

# %%
plt.scatter(CINE3["Time"], CINE3["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %%
CINE3.index[CINE3["Time"] > 800]
mayores_800_540 = CINE3[CINE3["Time"] > 800] #filtrado cccp

# %%
plt.scatter(mayores_800_540["Time"], -mayores_800_540["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Negativo

# %%
plt.scatter(NEG["Time"], NEG["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
plt.scatter(NEG["Time"], NEG["I2"], marker='o', color='crimson', label= 'I2=540 nm')
#plt.title('Cinética 0.5 s$\muL$')
plt.xlabel('Tiempo (s)') 
plt.ylabel('Intensidad')
plt.legend(loc="center left")
plt.grid()
plt.show()

fig, axs = plt.subplots(ncols=2, figsize=(7, 2.5), constrained_layout=True)
axs[0].scatter(NEG["Time"], NEG["I1"], marker='o', color='royalblue', label= 'I1=500 nm')
axs[0].legend()
axs[0].grid()
axs[1].scatter(NEG["Time"], NEG["I2"], marker='o', color='crimson', label= 'I2=540 nm')
axs[1].legend()
axs[1].grid()

# %%
plt.scatter(NEG["Time"], NEG["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
plt.ylim(0.45,0.5)
#plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Espectro

# %%
plt.scatter(MSC["EmissionWavelength"], MSC["Intensity"], marker='o', color='mediumseagreen', label= 'Sin CCCP')
plt.scatter(MCC["EmissionWavelength"], MCC["Intensity"], marker='o', color='chocolate', label= 'Con CCCP')
#plt.title('Espectro sin EDTA')
plt.xlabel('Longitud de Onda (nm)') 
plt.ylabel('Intensidad')
plt.legend()
plt.grid()
plt.show()
