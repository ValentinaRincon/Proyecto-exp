# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
def datos(archivo_csv):
    df = pd.read_csv(archivo_csv, sep=';')
    df_datos = df[["Time", "GPolarization", "I1", "I2"]]
    return df_datos

# %%
CIN = datos('CCCP_2muL DiOC cinética_1.csv')

# %%
plt.scatter(CIN["Time"], CIN["I1"], marker='o', color='darkorange', label= 'I1=500 nm')
plt.scatter(CIN["Time"], CIN["I2"], marker='o', color='brown', label= 'I2=520 nm')
#plt.title('Cinética 0.5 s$\muL$')
plt.xlabel('Tiempo (s)') 
plt.ylabel('Intensidad')
plt.legend()
plt.grid()
plt.show()
print("puntos escogidos para el caso de DiOC 2 muL: " + str(500) + "nm y " + str(520) + "nm")
# Out:
# puntos escogidos para el caso de DiOC 2 muL: 500nm y 520nm

# %%
plt.scatter(CIN["Time"], CIN["GPolarization"], marker='o', color='darkorange')
plt.xlabel('Tiempo (s)') 
plt.ylabel('GPolarization')
#plt.legend()
plt.ylim(0.0,0.4)
plt.grid()
plt.show()
